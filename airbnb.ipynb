# %% [markdown]
# # Poswork 4
# En este paso, se comenzó el análisis del conjunto de datos que fue seleccionado en la sección anterior.
# Para este primer análisis, se utiliza la biblioteca Pandas.
#
# El conjunto de datos representa el listado de propiedades Airbnb de las ciudades... (describir)

# %% [markdown]
# Para hacer uso de Pandas y Numpy es nesario importar las librerías.
#
# Para mayor información sobre [Pandas](https://pandas.pydata.org/docs/) y [Numpy](https://numpy.org/doc/) consultar la documentación.

# %%
#Importando librerias
import pandas as pd
import numpy as np

# %% [markdown]
# El conjunto de datos se encuentra almacedo en Google Drive, es necesario habilitar el acceso a Google Colaboratory con la finalidad de cargar los datos. Una forma de realizar este paso es ejecutar la siguiente línea.

# %%
from google.colab import drive
drive.mount('https://github.com/BeduDSEquipo9/G2DSF2_Python/blob/Developer/Datasets/airbnb.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_107408/3220764324.py in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('https://github.com/BeduDSEquipo9/G2DSF2_Python/blob/Developer/Datasets/airbnb.csv')
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# El conjunto de datos esta en formato csv, por lo que se utiliza `pd.read_csv()` para crear un objeto de tipo DataFrame.

# %%
data=pd.read_csv('/content/drive/MyDrive/BEDUDSF2M3Python2023Proy/Proy/Datasets/airbnb.csv')

# %% [markdown]
# Una vez cargados los datos en un DataFrame comenzaremos la exploración de los datos.
#
# Una primera vista a los datos se realiza con la ayuda de `head()`, que muestra los defecto los primeros diez regitros del DataFrame. Algo simiar con el método `tail()` que muesta los últimos registros del DataFrame.

# %%
data.head()
# Out:
#       id property_type        room_type  \
# 0  46459         House     Private room
# 1  16468     Apartment  Entire home/apt
# 2  30190     Apartment  Entire home/apt
# 3  43181     Townhouse     Private room
# 4  62109   Condominium  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             2        0.0
# 1  {Internet,"Wireless Internet",Kitchen,Heating,...             2        1.0
# 2  {TV,Internet,"Wireless Internet","Air conditio...             4        1.0
# 3  {"Wireless Internet","Air conditioning","Pets ...             3        1.0
# 4  {TV,"Cable TV",Internet,"Wireless Internet","A...             5        2.0
#
#    bed_type cancellation_policy  cleaning_fee     city  ...   longitude  \
# 0  Real Bed              strict          True      NYC  ...  -74.003574
# 1  Real Bed              strict          True       LA  ... -118.474525
# ...

# %%
data.tail()
# Out:
#           id property_type        room_type  \
# 59283  64666         House  Entire home/apt
# 59284  10864   Condominium  Entire home/apt
# 59285  14978     Apartment  Entire home/apt
# 59286  58971     Apartment  Entire home/apt
# 59287  35007         House  Entire home/apt
#
#                                                amenities  accommodates  \
# 59283  {TV,"Cable TV",Internet,"Wireless Internet","A...             5
# 59284  {TV,"Cable TV","Wireless Internet","Air condit...             2
# 59285  {TV,Internet,"Wireless Internet","Air conditio...             3
# 59286  {TV,"Wireless Internet","Air conditioning","Wh...             3
# 59287  {TV,"Cable TV",Internet,"Wireless Internet","A...            14
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee city  ...  \
# 59283        2.0  Real Bed            moderate          True   LA  ...
# 59284        1.5  Real Bed              strict          True  NYC  ...
# ...

# %% [markdown]
# El conjunto de datos Airbnb contiene 59,288 observaciones y 29 variables, de acuerdo don el resultado obtenido con el atributo `shape`

# %%
data.shape
# Out:
# (59288, 29)

# %% [markdown]
# El atributo `columns` permite obtener el nombre de cada una de las columnas del conjunto de datos.

# %%
data.columns
# Out:
# Index(['id', 'property_type', 'room_type', 'amenities', 'accommodates',
#        'bathrooms', 'bed_type', 'cancellation_policy', 'cleaning_fee', 'city',
#        'description', 'first_review', 'host_has_profile_pic',
#        'host_identity_verified', 'host_response_rate', 'host_since',
#        'instant_bookable', 'last_review', 'latitude', 'longitude', 'name',
#        'neighbourhood', 'number_of_reviews', 'review_scores_rating',
#        'thumbnail_url', 'zipcode', 'bedrooms', 'beds', 'price'],
#       dtype='object')

# %% [markdown]
# En resultado de la línea anterior muestra que los nombres de las columnas utilizan de manera estándarizada un formato de escritura `snake_case`. Además, se puede apreciar que cada uno de los nombres es representativo del dato que almacenan.

# %% [markdown]
# Para completar la información se utiliza el métodol `info()` se puede cononcer más detalles del dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59288 entries, 0 to 59287
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      59288 non-null  int64
#  1   property_type           59288 non-null  object
#  2   room_type               59288 non-null  object
#  3   amenities               59288 non-null  object
#  4   accommodates            59288 non-null  int64
#  5   bathrooms               59133 non-null  float64
#  6   bed_type                59288 non-null  object
#  7   cancellation_policy     59288 non-null  object
#  8   cleaning_fee            59288 non-null  bool
#  9   city                    59288 non-null  object
#  10  description             59288 non-null  object
#  11  first_review            46626 non-null  object
#  12  host_has_profile_pic    59137 non-null  object
#  13  host_identity_verified  59137 non-null  object
# ...

# %% [markdown]
# A continuación se utiliza el método `unique()` para conocer los valores unicos de algunas de las columnas que contienen tipos de datos categóricos:

# %%
data['property_type'].unique()
# Out:
# array(['House', 'Apartment', 'Townhouse', 'Condominium', 'Villa', 'Loft',
#        'Bed & Breakfast', 'Guesthouse', 'Other', 'Boutique hotel',
#        'Bungalow', 'Cabin', 'Boat', 'Hostel', 'Camper/RV', 'Guest suite',
#        'Dorm', 'Vacation home', 'In-law', 'Tent', 'Treehouse',
#        'Timeshare', 'Castle', 'Yurt', 'Tipi', 'Earth House',
#        'Serviced apartment', 'Hut', 'Island', 'Chalet', 'Train', 'Cave',
#        'Lighthouse'], dtype=object)

# %%
data['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
data['bed_type'].unique()
# Out:
# array(['Real Bed', 'Futon', 'Airbed', 'Pull-out Sofa', 'Couch'],
#       dtype=object)

# %%
data['cancellation_policy'].unique()
# Out:
# array(['strict', 'flexible', 'moderate', 'super_strict_30',
#        'super_strict_60'], dtype=object)

# %% [markdown]
# Despues de ejecutar las líneas anterioers, se resumen que las 29 variable son las siguientes:
#
# * `id` que es un valor numérico que identifica la propiedad lista en Airbnb y es de tipo `int64`
# * `property_type` es una valor categórico nominal que indica el tipo de propiedad: `House`, `Apartment`, `Townhouse`, `Condominium`, `Villa`, `Loft`, `Bed & Breakfast`, `Guesthouse`, `Other`, `Boutique hotel`,  `Bungalow`, `Cabin`, `Boat`, `Hostel`, `Camper/RV`, `Guest suite`,  `Dorm`, `Vacation home`, `In-law`, `Tent`, `Treehouse`,  `Timeshare`, `Castle`, `Yurt`, `Tipi`, `Earth House`,  `Serviced apartment`, `Hut`, `Island`, `Chalet`, `Train`, `Cave`,  `Lighthouse`. Es de tipo cadena de caracteres.
# *  `room_type` es un valor categórico nominal que indica el tipo de habitación. Por ejemplo, pude tomar valores como: `Entire home/apt`, `Private room` y `Shared room`.
# * `amenities`, las amenidades  son todos aquellos espacios o instalaciones dentro de una propiedad capaces de proporcionar una mejor calidad de vida. Por ende, son características que proporcionan un mayor valor al inmueble. El dato esta almacena en formato de cadena, donde se separan por coma cada una de las amenidades. Ejemplo: `{"TV", "Wireless Internet", "Air conditioning", "Wheelchair accessible", "Kitchen", "Breakfast"}`
# *  `accommodates` indica el número de personas máximo que pueden ser alojadas en la propiedad. El valor es un número entero positivo de tipo `int64`
# * `bathrooms` indica el número de baños que se disponen en la propiedad, el dato esta representado con `float64`.
# *  `bed_type`, especifica el tipo de cama. Por ejemplo: `Real bed`, `Futon`, `Sofa`, `Airbed`, `Pull-out Sofa`, `Couch`. Este dato esta representado mediante una cadena de texto.
# * `cancellation_policy`, es un valor categórico que indica la politica de cancelación: `strict`, `flexible`, `moderate`, `super_strict_30` `super_strict_60`, esta representado por una cadena de caracteres.
# * `cleaning_fee`, indica si existe tarifa de limpieza. Esta representado por un tipo booleano: `True` o `False`.
# * `city`, es un valor categórico ordinal que indica la ciudad donde se encuentra la propiedad. El valor esta representado por una cadena de caracteres.
# * `description`, es un texto que describe la propiedad y esta representado por una cadena de caracteres.
# * `first_review`, indica la fecha de la primera reseña realizada por un huésped. Es una cadena de caracteres que tiene la forma `AAAA-MM-DD`.
# * `host_has_profile_pic`, esta variable indica si el host a subido una foto de perfil a la plataforma de Airbnb. El dato esta representado por una cadena de caracteres, que solo contien una `t` o `f`.
# * `host_identity_verified`, este columa indica si el host a verificado su identidad en la plataforma de Airbnb. El dato esta representado por una cadena de caracteres, que solo contien una `t` o `f`.
# * `host_response_rate`, mide la frecuencia con que el host respondes las consultas y las solicitudes que recibe. Esta representado en una cadena de caracteres, por ejemplo: `"100%"`, `"99%"`, `"90%"`.
# * `host_since`, indica le fecha desde cuando el usuario esta registrado como host en la propiedad.  Es una cadena de caracteres que tiene la forma `AAAA-MM-DD`.
# * `instant_bookable`, indica si la propiedad puede ser reservada de manera inmediata sin tener que enviar una solicitud al anfitrión y esperar a que la apruebe.  El dato esta representado por una cadena de caracteres, que solo contien una `t` o `f`.
# * `last_review`, específica le fecha de la última vez que la propiedad tuvo una reseña.  Es una cadena de caracteres que tiene la forma `AAAA-MM-DD`.
# * Las variables `latitude` y `longitude`, determinan la posiciòn geospacial de la propiedad, esta con cierto rango de desviación por fines de propiedad. Ambas columnas estan representadas con un dato de tipo `float64`.
# * `name`, describe el título que identifica a la propiedad en la plataforma Airbnb, tiene un formato de cadena de caracteres.
# * `neighbourhood`, indica el vecindario (colonia) de la propiedad. Esta en formato de cadena de caracteres.
# * `number_of_reviews`, indica el número de reseñas que ha tenido la propiedad. El valor es un número entero positivo de tipo `int64`.
# * `review_scores_rating`, especifica la calificación de las reseñas dada en una escala de 0 a 100. Esta variable esta representada con un valor de  tipo `float64`.
# * `thumbnail_url`, Es una dirección url del thumbnail de la propiedad. Esta url esta representada por una cadena de caracteres.
# * `zipcode`, el código postal de la dirección de la propiedad. Es un valor entero de hasta cinco dígitos que esta representado por un valor de tipo cadena de caracteres.
# * `bedrooms`, indica el número de habitaciones de la propieda y esta representado por una numero de tipo `float64`.
# * `beds`,  esta variable indica el número de camas en la propieday esta representado por una numero de tipo `float64`.
# * `price`, especifica el costo de renta de la propiedad. Es una variable que esta representada por un dato de tipo `float64`.

# %% [markdown]
# En algunos casos se observa que el tipo de dato no es el correcto, ya que no es adecuado al valor que representa. Por lo que será necesario cambiar el tipo de de dato adecuado, en pasos posteriores.
#
# * Las variabes `host_has_profile_pic`, `host_identity_verified` e `instant_bookable`, serán convertidas a tipo Booleano, ya que actualmente esta representadas por una cadena de caracteres, que solo contien una t o f.
#
# * Las `host_response_rate`, `zipcode` estan representadas con cadena de caracteres. Por lo que se modificará a un tipo `int64`.

# %% [markdown]
# Para continuar con la exploración de los datos, utilzamos la indexación `loc` y `iloc`.
#
# Por ejemplo, acomtinuación obtenemos todas las columnas del indice `179` con la ayuda de `loc`:

# %%
data.loc[179, :]
# Out:
# id                                                                    41118
# property_type                                                         House
# room_type                                                      Private room
# amenities                 {TV,Internet,"Wireless Internet","Air conditio...
# accommodates                                                              2
# bathrooms                                                               1.0
# bed_type                                                           Real Bed
# cancellation_policy                                                  strict
# cleaning_fee                                                           True
# city                                                                     LA
# description               新主人,新装修屋,干净舒适,使用中央冷暖气,非常安静,靠近公共交通,中西餐馆,超市,银行,大...
# first_review                                                     2017-04-02
# ...

# %% [markdown]
# De manera analoga se puede realizar con `iloc`:

# %%
data.iloc[179, :]
# Out:
# id                                                                    41118
# property_type                                                         House
# room_type                                                      Private room
# amenities                 {TV,Internet,"Wireless Internet","Air conditio...
# accommodates                                                              2
# bathrooms                                                               1.0
# bed_type                                                           Real Bed
# cancellation_policy                                                  strict
# cleaning_fee                                                           True
# city                                                                     LA
# description               新主人,新装修屋,干净舒适,使用中央冷暖气,非常安静,靠近公共交通,中西餐馆,超市,银行,大...
# first_review                                                     2017-04-02
# ...

# %% [markdown]
# Se puede obtener una columna en particular con `loc` y con `iloc`:

# %%
data.loc[: , 'host_response_rate']
# Out:
# 0        100%
# 1         NaN
# 2         80%
# 3        100%
# 4        100%
#          ...
# 59283    100%
# 59284    100%
# 59285     33%
# 59286     86%
# 59287     84%
# Name: host_response_rate, Length: 59288, dtype: object

# %%
data.iloc[: , 14]
# Out:
# 0        100%
# 1         NaN
# 2         80%
# 3        100%
# 4        100%
#          ...
# 59283    100%
# 59284    100%
# 59285     33%
# 59286     86%
# 59287     84%
# Name: host_response_rate, Length: 59288, dtype: object

# %% [markdown]
# Después de seleccionar algunas filas y columnas al azar  nos encontramos con que hay datos faltantes en ciertos registros. Esto se pude confirmar desde que se ejecuto el método `info()` y la columna Non-null muestra en algunas variables muestran un valor distinto al número de observaciones (59,288).
# En el caso de la variable `host_response_rate` vemos que el símbolo de `%` representa un riesgo al momento de desear realizar una conversión a tipo entero, por lo que hay que eliminar ese símbolo pare evitar errores al moemto de aplicar `casting`. Todas las columnas que representa fechas, será necesario realizar el cambio a un tipo `Date`.

# %% [markdown]
# En conclusión, después del análisis de los datos se ha determinado que el conjunto de datos recopilado puede responder todas las preguntas planteadas al inicio de este trabajo.

# %% [markdown]
# # Poswork 5

# %% [markdown]
# Después de realizar la primera exploración, es necesario realizar la limpieza del DataFrame.
# Como se mencionó anteriormente algunas de las columnas en el Dataframe contienen `Nan`.
# En esta sección decidiremos si aquellos `Nan` implicar eliminar una columna o solo elimiar algunos registros. Incluso, se pudee considerar la posibilidaded de llenar estos valores `NaN` con alguna valor en partícular. Verificaremos nuevamente  con la ayuda de `isna()` y la función de agregación `sum()` los datos `NaN`.

# %%
data.isna().sum()
# Out:
# id                            0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   155
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# description                   0
# first_review              12662
# host_has_profile_pic        151
# host_identity_verified      151
# host_response_rate        14558
# host_since                  151
# instant_bookable              0
# last_review               12633
# latitude                      0
# longitude                     0
# name                          0
# neighbourhood              5513
# number_of_reviews             0
# review_scores_rating      13341
# thumbnail_url              6520
# zipcode                     789
# bedrooms                     71
# beds                        106
# price                         0
# ...

# %% [markdown]
# Deforma similar se puede llegar un resume para conocer el número de `NaN`en cada fila.

# %%
data.isna().sum(axis=1)
# Out:
# 0        0
# 1        2
# 2        0
# 3        0
# 4        0
#         ..
# 59283    0
# 59284    0
# 59285    3
# 59286    0
# 59287    2
# Length: 59288, dtype: int64

# %% [markdown]
# Comenzaremos revisando la columna `review_scores_rationg` que tiene un total de 13,341 valores `NaN` para determinar si es conveniente o no eliminarla, se debe analizar si esta columna es un determinante para el problema abordado en este tranbajo, es decir, predecir el costo que debe tener un propiedad a ser rentada en Airbnb.

# %%
# Out:
# 45947

# %% [markdown]
# De aquí en adelante es lo que tenia Francisco

# %% [markdown]
# buuscando datos mas actuales por Last_review

# %%
data.sort_values(by=['last_review'],ascending=False)
# Out:
#           id property_type        room_type  \
# 6214   11164         House     Private room
# 32044  54119   Condominium     Private room
# 4550   33581   Condominium     Private room
# 21118  35946         House     Private room
# 46802  64110     Apartment     Private room
# ...      ...           ...              ...
# 59272   7102     Apartment     Private room
# 59274  26020         House      Shared room
# 59279  10637         House  Entire home/apt
# 59281  14939     Apartment     Private room
# 59285  14978     Apartment  Entire home/apt
#
#                                                amenities  accommodates  \
# 6214   {TV,"Wireless Internet",Kitchen,"Free parking ...             2
# 32044  {"Wireless Internet","Air conditioning","Free ...             2
# 4550   {"Wireless Internet","Air conditioning",Heatin...             2
# 21118  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 46802  {TV,"Wireless Internet",Kitchen,"Free parking ...             2
# ...

# %% [markdown]
# - Crear nuevas columnas en un `DataFrame`
# - Reasignar columnas
# - Eliminar columnas

# %%
#data_2 = data.drop(columns=['BuildingArea', 'YearBuilt'])

# %%
#data_2['Regionname'] = data_2['Regionname'].fillna('Unknown')

# %%
#data_dropped = data_2.dropna(axis=0, how='any')

# %%
data_dropped=data

# %% [markdown]
# Ahora, tenemos dos situaciones:
#
# 1. La primera es que nuestro índice no coincide con el número de filas que tenemos. En este caso, dado que nuestro índice es secuencial y numérico, y no tiene ningún significado además de eso, nos convendría que reflejara la cantidad de filas que tenemos en nuestro dataset.
#
# Para lograr eso vamos a usar el método `reset_index`:

# %%
data.reset_index(inplace=True)

# %%
data.head(5)
# Out:
#    index     id property_type        room_type  \
# 0      0  46459         House     Private room
# 1      1  16468     Apartment  Entire home/apt
# 2      2  30190     Apartment  Entire home/apt
# 3      3  43181     Townhouse     Private room
# 4      4  62109   Condominium  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             2        0.0
# 1  {Internet,"Wireless Internet",Kitchen,Heating,...             2        1.0
# 2  {TV,Internet,"Wireless Internet","Air conditio...             4        1.0
# 3  {"Wireless Internet","Air conditioning","Pets ...             3        1.0
# 4  {TV,"Cable TV",Internet,"Wireless Internet","A...             5        2.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   longitude  \
# 0  Real Bed              strict          True  ...  -74.003574
# 1  Real Bed              strict          True  ... -118.474525
# ...

# %% [markdown]
# Nuestro índice ya está correcto, pero ahora tenemos un columna llamada `index` que contiene el índice original. Como no queremos guardar esos datos, agregamos la opción `drop=True` para eliminar el índice anterior:

# %%
#df_dropped.reset_index(drop=True)

# %%
#df_dropped = df_dropped.reset_index(drop=True)
